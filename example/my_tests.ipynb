# %% [markdown]
# # Tests with `parquet` format
# Link of documentation: https://arrow.apache.org/docs/python/parquet.html

# %% [markdown]
# ## Imports

# %%
import pyarrow.parquet as pq

# %%
import numpy as np
import pandas as pd
import pyarrow as pa

df = pd.DataFrame({'one': [-1, np.nan, 2.5],
                   'two': ['foo', 'bar', 'baz'],
                   'three': [True, False, True]},
                   index=list('abc'))

table = pa.Table.from_pandas(df)
table.to_pandas()
# Out:
#    one  two  three
# a -1.0  foo   True
# b  NaN  bar  False
# c  2.5  baz   True

# %%
# Writing to file
fname = 'example.parquet'
pq.write_table(table, fname)

# %%
table2 = pq.read_table(fname)
table2.to_pandas()
# Out:
#    one  two  three
# a -1.0  foo   True
# b  NaN  bar  False
# c  2.5  baz   True

# %%
# Install and load DuckDB spatial extension
duckdb.install_extension("spatial")
duckdb.load_extension("spatial")

# %%
s2_parquet_path = "s2-stac-api.parquet"

# %% [markdown]
# ## Query the geoparquet file

# %%
if not os.path.exists(s2_parquet_path):
    print("Run notebook 02-Create a geoparquet file.ipynb first")
    exit(1)

# %%
sql_query = f"SELECT * EXCLUDE(geometry), ST_AsWKB(geometry) as geometry FROM '{s2_parquet_path}'"

print(sql_query)

db = duckdb.query(sql_query)
# Out:
# SELECT * EXCLUDE(geometry), ST_AsWKB(geometry) as geometry FROM 's2-stac-api.parquet'

# %%
type(db)
# Out:
# duckdb.duckdb.DuckDBPyRelation

# %% [markdown]
# ## Convert DuckDB result to Arrow table

# %%
table = db.fetch_arrow_table()

table_head = table.slice(0, 125)  # Get first 125 rows

# %%
table.slice(0, 1)
# Out:
# pyarrow.Table
# assets: struct<AOT: struct<gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B01: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B02: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B03: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B04: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B05: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B06: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B07: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B08: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B09: struct<eo:bands: list<l: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B11: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B12: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>, B8A: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, ti ...
#   child 0, AOT: struct<gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, gsd: double
#       child 1, href: string
#       child 2, proj:bbox: list<l: double>
#           child 0, l: double
#       child 3, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 4, proj:transform: list<l: double>
#           child 0, l: double
#       child 5, roles: list<l: string>
#           child 0, l: string
#       child 6, title: string
#       child 7, type: string
#   child 1, B01: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 2, B02: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 3, B03: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 4, B04: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 5, B05: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 6, B06: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 7, B07: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 8, B08: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 9, B09: struct<eo:bands: list<l: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, description: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 10, B11: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 11, B12: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 12, B8A: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
#   child 13, SCL: struct<gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, gsd: double
#       child 1, href: string
#       child 2, proj:bbox: list<l: double>
#           child 0, l: double
#       child 3, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 4, proj:transform: list<l: double>
#           child 0, l: double
#       child 5, roles: list<l: string>
#           child 0, l: string
#       child 6, title: string
#       child 7, type: string
#   child 14, WVP: struct<gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, gsd: double
#       child 1, href: string
#       child 2, proj:bbox: list<l: double>
#           child 0, l: double
#       child 3, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 4, proj:transform: list<l: double>
#           child 0, l: double
#       child 5, roles: list<l: string>
#           child 0, l: string
#       child 6, title: string
#       child 7, type: string
#   child 15, datastrip-metadata: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 16, granule-metadata: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 17, inspire-metadata: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 18, preview: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 19, product-metadata: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 20, rendered_preview: struct<href: string, rel: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, rel: string
#       child 2, roles: list<l: string>
#           child 0, l: string
#       child 3, title: string
#       child 4, type: string
#   child 21, safe-manifest: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 22, tilejson: struct<href: string, roles: list<l: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<l: string>
#           child 0, l: string
#       child 2, title: string
#       child 3, type: string
#   child 23, visual: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#       child 0, eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<l: double>
#           child 0, l: double
#       child 4, proj:shape: list<l: int64>
#           child 0, l: int64
#       child 5, proj:transform: list<l: double>
#           child 0, l: double
#       child 6, roles: list<l: string>
#           child 0, l: string
#       child 7, title: string
#       child 8, type: string
# bbox: struct<xmin: double, ymin: double, xmax: double, ymax: double>
#   child 0, xmin: double
#   child 1, ymin: double
#   child 2, xmax: double
#   child 3, ymax: double
# collection: string
# id: string
# links: list<l: struct<href: string, rel: string, title: string, type: string>>
#   child 0, l: struct<href: string, rel: string, title: string, type: string>
#       child 0, href: string
#       child 1, rel: string
#       child 2, title: string
#       child 3, type: string
# stac_extensions: list<l: string>
#   child 0, l: string
# stac_version: string
# type: string
# constellation: string
# datetime: timestamp[us, tz=Etc/UTC]
# eo:cloud_cover: double
# instruments: list<l: string>
#   child 0, l: string
# platform: string
# proj:code: string
# s2:cloud_shadow_percentage: double
# s2:dark_features_percentage: double
# s2:datastrip_id: string
# s2:datatake_id: string
# s2:datatake_type: string
# s2:degraded_msi_data_percentage: double
# s2:generation_time: string
# s2:granule_id: string
# s2:high_proba_clouds_percentage: double
# s2:mean_solar_azimuth: double
# s2:mean_solar_zenith: double
# s2:medium_proba_clouds_percentage: double
# s2:mgrs_tile: string
# s2:nodata_pixel_percentage: double
# s2:not_vegetated_percentage: double
# s2:processing_baseline: string
# s2:product_type: string
# s2:product_uri: string
# s2:reflectance_conversion_factor: double
# s2:saturated_defective_pixel_percentage: double
# s2:snow_ice_percentage: double
# s2:thin_cirrus_percentage: double
# s2:unclassified_percentage: double
# s2:vegetation_percentage: double
# s2:water_percentage: double
# sat:orbit_state: string
# sat:relative_orbit: int64
# geometry: binary
# ----
# assets: [
# ]
# bbox: [
# ]
# collection: []
# id: []
# links: []
# stac_extensions: []
# stac_version: []
# type: []
# constellation: []
# datetime: []
# ...

# %%
for item in stac_table_to_items(table_head):
    print(item)

# %% [markdown]
# ## Map

# %%
items = [pystac.Item.from_dict(item) for item in stac_table_to_items(table_head)]
items
# Out:
# []

# %%
items = [pystac.Item.from_dict(item) for item in stac_table_to_items(table_head)]

map = folium.Map()
layer_control = folium.LayerControl(position="topright", collapsed=True)
fullscreen = folium_plugins.Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints = folium.GeoJson(
    gpd.GeoDataFrame.from_features(items).to_json(),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds())
map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 9
#       5 fullscreen = folium_plugins.Fullscreen()
#       6 style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}
#       8 footprints = folium.GeoJson(
# ----> 9     gpd.GeoDataFrame.from_features(items).to_json(),
#      10     name="Stac Item footprints",
#      11     style_function=lambda x: style,
#      12     control=True,
#      13 )
#      15 footprints.add_to(map)
#      16 layer_control.add_to(map)
#
# File ~/.envs/env_sprint6/lib/python3.13/site-packages/geopandas/geodataframe.py:944, in GeoDataFrame.to_json(self, na, show_bbox, drop_id, to_wgs84, **kwargs)
#     941 else:
#     942     df = self
# --> 944 geo = df.to_geo_dict(na=na, show_bbox=show_bbox, drop_id=drop_id)
#     946 # if the geometry is not in WGS84, include CRS in the JSON
#     947 if df.crs is not None and not df.crs.equals("epsg:4326"):
#
# File ~/.envs/env_sprint6/lib/python3.13/site-packages/geopandas/geodataframe.py:1154, in GeoDataFrame.to_geo_dict(self, na, show_bbox, drop_id)
#    1106 def to_geo_dict(self, na="null", show_bbox=False, drop_id=False):
#    1107     """
#    1108     Returns a python feature collection representation of the GeoDataFrame
#    1109     as a dictionary with a list of features based on the ``__geo_interface__``
#    (...)   1150
#    1151     """
#    1152     geo = {
#    1153         "type": "FeatureCollection",
# -> 1154         "features": list(
#    1155             self.iterfeatures(na=na, show_bbox=show_bbox, drop_id=drop_id)
#    1156         ),
#    1157     }
#    1159     if show_bbox:
#    1160         geo["bbox"] = tuple(self.total_bounds)
#
# File ~/.envs/env_sprint6/lib/python3.13/site-packages/geopandas/geodataframe.py:1041, in GeoDataFrame.iterfeatures(self, na, show_bbox, drop_id)
#    1038     raise ValueError("Unknown na method {0}".format(na))
#    1040 if self._geometry_column_name not in self:
# -> 1041     raise AttributeError(
#    1042         "No geometry data set (expected in column '%s')."
#    1043         % self._geometry_column_name
#    1044     )
#    1046 ids = np.array(self.index, copy=False)
#    1047 geometries = np.array(self[self._geometry_column_name], copy=False)
#
# AttributeError: No geometry data set (expected in column 'None').

# %% [markdown]
# ### Geofilter

# %%
cql2_filter = {
    "op": "and",
    "args": [
        {
            "op": "between",
            "args": [
                {"property": "datetime"},
                ["2023-12-28T00:00:00Z", "2023-12-28T23:59:59Z"],
            ],
        },
        {"op": "between", "args": [{"property": "eo:cloud_cover"}, [90, 100]]},
        {
            "op": "s_intersects",
            "args": [
                {"property": "geometry"},
                {
                    "type": "Polygon",
                    "coordinates": [
                        [
                            [-9.51346013858793, 38.95450355515311],
                            [-9.51346013858793, 38.22500810801125],
                            [-8.359265560322228, 38.22500810801125],
                            [-8.359265560322228, 38.95450355515311],
                            [-9.51346013858793, 38.95450355515311],
                        ]
                    ],
                },
            ],
        },
    ],
}

# %%
sql_where = to_sql_where(json_parse(cql2_filter), IdempotentDict())
print(sql_where)

# %%
sql_query = f"SELECT * EXCLUDE(geometry), ST_AsWKB(geometry) as geometry FROM '{s2_parquet_path}' WHERE {sql_where}"

# %%
db = duckdb.query(sql_query)

# %%
subset_table = db.fetch_arrow_table()
subset_table[0]

# %%
items = [pystac.Item.from_dict(item) for item in stac_table_to_items(subset_table)]

items[0]

# %%
len(items)

# %%
map = folium.Map()
layer_control = folium.LayerControl(position="topright", collapsed=True)
fullscreen = folium_plugins.Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints = folium.GeoJson(
    gpd.GeoDataFrame.from_features(items).to_json(),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds())
map
