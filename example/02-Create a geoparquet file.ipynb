# %% [markdown]
# # Create a geoparquet file

# %%
import pystac_client
import json
from pathlib import Path
from stac_geoparquet.arrow import parse_stac_ndjson_to_arrow, to_parquet
from pyarrow.parquet import read_table

# %% [markdown]
# ## Query a STAC API endpoint

# %%
# STAC API Endpoint
stac_url = "https://planetarycomputer.microsoft.com/api/stac/v1"  

# Define Time Range
start_date = "2023-01-01"
end_date = "2023-12-31"
date_range = f"{start_date}/{end_date}"

# AOI for our collection
geometry = {
    "type": "Polygon",
    "coordinates": [
        [
            [-9.775114442649567, 44.141939637656606],
            [-9.775114442649567, 35.48272079491679],
            [1.302203384529662, 35.48272079491679],
            [1.302203384529662, 44.141939637656606],
            [-9.775114442649567, 44.141939637656606]
        ]
    ]
}

# Connect to STAC API
catalog = pystac_client.Client.open(stac_url)

# Search for Items
search = catalog.search(
    collections=["sentinel-2-l2a"],  
    intersects=geometry,  
    datetime=date_range,  
    
    max_items=1000  )

# %% [markdown]
# ## Create a JSONl file

# %% [markdown]
# The JSON Lines text format, also called newline-delimited JSON, is a convenient format for storing structured data that may be processed one record at a time.
#
# Create a jsonl file with one feature (STAC Item) per line

# %%
items_iter = search.items()

max_items = 1000
s2_json_path = Path("sentinel-2-l2a.jsonl")
if not s2_json_path.exists():
    with open(s2_json_path, "w") as f:
        count = 0

        for item in items_iter:
            json.dump(item.to_dict(), f, separators=(",", ":"))
            f.write("\n")

            count += 1
            if count >= max_items:
                break

# %% [markdown]
# ## Create a record batch reader
#
# Use `stac_geoparquet.arrow.parse_stac_ndjson_to_arrow` to create an Apache Arrow record batch reader
#
# See:
#
# * `stac_geoparquet.arrow.parse_stac_ndjson_to_arrow` [https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.parse_stac_ndjson_to_arrow](https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.parse_stac_ndjson_to_arrow)
# * `RecordBatchReader` [https://arrow.apache.org/docs/python/generated/pyarrow.RecordBatchReader.html#pyarrow.RecordBatchReader](https://arrow.apache.org/docs/python/generated/pyarrow.RecordBatchReader.html#pyarrow.RecordBatchReader)

# %%
record_batch_reader = parse_stac_ndjson_to_arrow(s2_json_path)

# %% [markdown]
# ## Create a `pyarrow.lib.Table`
#
# See  [https://arrow.apache.org/docs/python/generated/pyarrow.Table.html#pyarrow-table](https://arrow.apache.org/docs/python/generated/pyarrow.Table.html#pyarrow-table)

# %%
table = record_batch_reader.read_all()

table.schema
# Out:
# assets: struct<AOT: struct<gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B01: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B02: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B03: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B04: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B05: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B06: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B07: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B08: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B09: struct<eo:bands: list<item: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B11: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B12: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>, B8A: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_wi ...
#   child 0, AOT: struct<gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, gsd: double
#       child 1, href: string
#       child 2, proj:bbox: list<item: double>
#           child 0, item: double
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: double>
#           child 0, item: double
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 1, B01: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 2, B02: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 3, B03: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 4, B04: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 5, B05: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 6, B06: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 7, B07: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 8, B08: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 9, B09: struct<eo:bands: list<item: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, description: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 10, B11: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 11, B12: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 12, B8A: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
#   child 13, SCL: struct<gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, gsd: double
#       child 1, href: string
#       child 2, proj:bbox: list<item: double>
#           child 0, item: double
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: double>
#           child 0, item: double
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 14, WVP: struct<gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, gsd: double
#       child 1, href: string
#       child 2, proj:bbox: list<item: double>
#           child 0, item: double
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: double>
#           child 0, item: double
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 15, datastrip-metadata: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 16, granule-metadata: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 17, inspire-metadata: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 18, preview: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 19, product-metadata: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 20, rendered_preview: struct<href: string, rel: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, rel: string
#       child 2, roles: list<item: string>
#           child 0, item: string
#       child 3, title: string
#       child 4, type: string
#   child 21, safe-manifest: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 22, tilejson: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 23, visual: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, description: string
#               child 3, full_width_half_max: double
#               child 4, name: string
#       child 1, gsd: double
#       child 2, href: string
#       child 3, proj:bbox: list<item: double>
#           child 0, item: double
#       child 4, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 5, proj:transform: list<item: double>
#           child 0, item: double
#       child 6, roles: list<item: string>
#           child 0, item: string
#       child 7, title: string
#       child 8, type: string
# bbox: struct<xmin: double, ymin: double, xmax: double, ymax: double>
#   child 0, xmin: double
#   child 1, ymin: double
#   child 2, xmax: double
#   child 3, ymax: double
# collection: string
# geometry: binary
#   -- field metadata --
#   ARROW:extension:name: 'geoarrow.wkb'
#   ARROW:extension:metadata: '{"crs":{"$schema":"https://proj.org/schemas/' + 1380
# id: string
# links: list<item: struct<href: string, rel: string, title: string, type: string>>
#   child 0, item: struct<href: string, rel: string, title: string, type: string>
#       child 0, href: string
#       child 1, rel: string
#       child 2, title: string
#       child 3, type: string
# stac_extensions: list<item: string>
#   child 0, item: string
# stac_version: string
# type: string
# constellation: string
# datetime: timestamp[us, tz=UTC]
# eo:cloud_cover: double
# instruments: list<item: string>
#   child 0, item: string
# platform: string
# proj:code: string
# s2:cloud_shadow_percentage: double
# s2:dark_features_percentage: double
# s2:datastrip_id: string
# s2:datatake_id: string
# s2:datatake_type: string
# s2:degraded_msi_data_percentage: double
# s2:generation_time: string
# s2:granule_id: string
# s2:high_proba_clouds_percentage: double
# s2:mean_solar_azimuth: double
# s2:mean_solar_zenith: double
# s2:medium_proba_clouds_percentage: double
# s2:mgrs_tile: string
# s2:nodata_pixel_percentage: double
# s2:not_vegetated_percentage: double
# s2:processing_baseline: string
# s2:product_type: string
# s2:product_uri: string
# s2:reflectance_conversion_factor: double
# s2:saturated_defective_pixel_percentage: double
# s2:snow_ice_percentage: double
# s2:thin_cirrus_percentage: double
# s2:unclassified_percentage: double
# s2:vegetation_percentage: double
# s2:water_percentage: double
# sat:orbit_state: string
# sat:relative_orbit: int64

# %% [markdown]
# Inspect the first row

# %%
table[0]
# Out:
# <pyarrow.lib.ChunkedArray object at 0x7239f41ff0a0>
# [
#   -- is_valid: all not null
#   -- child 0 type: struct<gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: double
#       [
#         10,
#         10,
#         10,
#         10,
#         10,
#         ...
#         10,
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 1 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R10m/T29TMJ_20231231T114409_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R10m/T31TCK_20231231T105441_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R10m/T31TCJ_20231231T105441_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R10m/T31TCH_20231231T105441_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R10m/T31TCG_20231231T105441_AOT_10m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R10m/T30SWF_20231211T105431_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R10m/T30SWE_20231211T105431_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R10m/T30SVF_20231211T105431_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R10m/T30SVE_20231211T105431_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R10m/T30TUQ_20231210T112451_AOT_10m.tif"
#       ]
#     -- child 2 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         ...
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<item: double>
#       [
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4900020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ],
#         ...
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4000020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         ...
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 1 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         60,
#         60,
#         60,
#         60,
#         60,
#         ...
#         60,
#         60,
#         60,
#         60,
#         60
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R60m/T29TMJ_20231231T114409_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R60m/T31TCK_20231231T105441_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R60m/T31TCJ_20231231T105441_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R60m/T31TCH_20231231T105441_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R60m/T31TCG_20231231T105441_B01_60m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R60m/T30SWF_20231211T105431_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R60m/T30SWE_20231211T105431_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R60m/T30SVF_20231211T105431_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R60m/T30SVE_20231211T105431_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R60m/T30TUQ_20231210T112451_B01_60m.tif"
#       ]
#     -- child 3 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ],
#         ...
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ]
#       ]
#     -- child 5 type: list<item: double>
#       [
#         [
#           60,
#           0,
#           399960,
#           0,
#           -60,
#           4900020
#         ],
#         [
#           60,
#           0,
#           300000,
#           0,
#           -60,
#           5000040
#         ],
#         ...
#         [
#           60,
#           0,
#           399960,
#           0,
#           -60,
#           4000020
#         ],
#         [
#           60,
#           0,
#           300000,
#           0,
#           -60,
#           5000040
#         ]
#       ]
#     -- child 6 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         ...
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 2 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10,
#         10,
#         ...
#         10,
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R10m/T29TMJ_20231231T114409_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R10m/T31TCK_20231231T105441_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R10m/T31TCJ_20231231T105441_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R10m/T31TCH_20231231T105441_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R10m/T31TCG_20231231T105441_B02_10m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R10m/T30SWF_20231211T105431_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R10m/T30SWE_20231211T105431_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R10m/T30SVF_20231211T105431_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R10m/T30SVE_20231211T105431_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R10m/T30TUQ_20231210T112451_B02_10m.tif"
#       ]
#     -- child 3 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         ...
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<item: double>
#       [
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4900020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ],
#         ...
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4000020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ]
#       ]
#     -- child 6 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         ...
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 3 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10,
#         10,
#         ...
#         10,
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R10m/T29TMJ_20231231T114409_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R10m/T31TCK_20231231T105441_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R10m/T31TCJ_20231231T105441_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R10m/T31TCH_20231231T105441_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R10m/T31TCG_20231231T105441_B03_10m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R10m/T30SWF_20231211T105431_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R10m/T30SWE_20231211T105431_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R10m/T30SVF_20231211T105431_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R10m/T30SVE_20231211T105431_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R10m/T30TUQ_20231210T112451_B03_10m.tif"
#       ]
#     -- child 3 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         ...
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<item: double>
#       [
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4900020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ],
#         ...
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4000020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ]
#       ]
#     -- child 6 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         ...
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 4 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10,
#         10,
#         ...
#         10,
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R10m/T29TMJ_20231231T114409_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R10m/T31TCK_20231231T105441_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R10m/T31TCJ_20231231T105441_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R10m/T31TCH_20231231T105441_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R10m/T31TCG_20231231T105441_B04_10m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R10m/T30SWF_20231211T105431_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R10m/T30SWE_20231211T105431_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R10m/T30SVF_20231211T105431_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R10m/T30SVE_20231211T105431_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R10m/T30TUQ_20231210T112451_B04_10m.tif"
#       ]
#     -- child 3 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         ...
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<item: double>
#       [
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4900020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ],
#         ...
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4000020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ]
#       ]
#     -- child 6 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         ...
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 5 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         20,
#         20,
#         20,
#         20,
#         20,
#         ...
#         20,
#         20,
#         20,
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R20m/T29TMJ_20231231T114409_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R20m/T31TCK_20231231T105441_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R20m/T31TCJ_20231231T105441_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R20m/T31TCH_20231231T105441_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R20m/T31TCG_20231231T105441_B05_20m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R20m/T30SWF_20231211T105431_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R20m/T30SWE_20231211T105431_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R20m/T30SVF_20231211T105431_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R20m/T30SVE_20231211T105431_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R20m/T30TUQ_20231210T112451_B05_20m.tif"
#       ]
#     -- child 3 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         ...
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 5 type: list<item: double>
#       [
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4900020
#         ],
#         [
#           20,
#           0,
#           300000,
#           0,
#           -20,
#           5000040
#         ],
#         ...
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4000020
#         ],
#         [
#           20,
#           0,
#           300000,
#           0,
#           -20,
#           5000040
#         ]
#       ]
#     -- child 6 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         ...
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 6 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         20,
#         20,
#         20,
#         20,
#         20,
#         ...
#         20,
#         20,
#         20,
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R20m/T29TMJ_20231231T114409_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R20m/T31TCK_20231231T105441_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R20m/T31TCJ_20231231T105441_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R20m/T31TCH_20231231T105441_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R20m/T31TCG_20231231T105441_B06_20m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R20m/T30SWF_20231211T105431_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R20m/T30SWE_20231211T105431_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R20m/T30SVF_20231211T105431_B06_20m.tif",
# ...
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231210T112451_R037_T30TUQ_20231210T171344&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png"
#       ]
#     -- child 1 type: string
#       [
#         "preview",
#         "preview",
#         "preview",
#         "preview",
#         "preview",
#         ...
#         "preview",
#         "preview",
#         "preview",
#         "preview",
#         "preview"
#       ]
#     -- child 2 type: list<item: string>
#       [
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ],
#         ...
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ]
#       ]
#     -- child 3 type: string
#       [
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview",
#         ...
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview"
#       ]
#     -- child 4 type: string
#       [
#         "image/png",
#         "image/png",
#         "image/png",
#         "image/png",
#         "image/png",
#         ...
#         "image/png",
#         "image/png",
#         "image/png",
#         "image/png",
#         "image/png"
#       ]
#   -- child 21 type: struct<href: string, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/manifest.safe",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/manifest.safe"
#       ]
#     -- child 1 type: list<item: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         ...
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest",
#         ...
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest"
#       ]
#     -- child 3 type: string
#       [
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         ...
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml"
#       ]
#   -- child 22 type: struct<href: string, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231231T114409_R123_T29TMJ_20231231T150806&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231231T105441_R051_T31TCK_20231231T162343&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231231T105441_R051_T31TCJ_20231231T162355&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231231T105441_R051_T31TCH_20231231T162350&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231231T105441_R051_T31TCG_20231231T162354&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         ...
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231211T105431_R051_T30SWF_20231211T161419&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231211T105431_R051_T30SWE_20231211T161414&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231211T105431_R051_T30SVF_20231211T161404&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231211T105431_R051_T30SVE_20231211T161405&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2A_MSIL2A_20231210T112451_R037_T30TUQ_20231210T171344&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png"
#       ]
#     -- child 1 type: list<item: string>
#       [
#         [
#           "tiles"
#         ],
#         [
#           "tiles"
#         ],
#         ...
#         [
#           "tiles"
#         ],
#         [
#           "tiles"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         ...
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering"
#       ]
#     -- child 3 type: string
#       [
#         "application/json",
#         "application/json",
#         "application/json",
#         "application/json",
#         "application/json",
#         ...
#         "application/json",
#         "application/json",
#         "application/json",
#         "application/json",
#         "application/json"
#       ]
#   -- child 23 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<item: double>, proj:shape: list<item: int64>, proj:transform: list<item: double>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         ...
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10,
#         10,
#         ...
#         10,
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/T/MJ/2023/12/31/S2B_MSIL2A_20231231T114409_N0510_R123_T29TMJ_20231231T150806.SAFE/GRANULE/L2A_T29TMJ_A035613_20231231T114858/IMG_DATA/R10m/T29TMJ_20231231T114409_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CK/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCK_20231231T162343.SAFE/GRANULE/L2A_T31TCK_A044521_20231231T105442/IMG_DATA/R10m/T31TCK_20231231T105441_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CJ/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCJ_20231231T162355.SAFE/GRANULE/L2A_T31TCJ_A044521_20231231T105442/IMG_DATA/R10m/T31TCJ_20231231T105441_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CH/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCH_20231231T162350.SAFE/GRANULE/L2A_T31TCH_A044521_20231231T105442/IMG_DATA/R10m/T31TCH_20231231T105441_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/31/T/CG/2023/12/31/S2A_MSIL2A_20231231T105441_N0510_R051_T31TCG_20231231T162354.SAFE/GRANULE/L2A_T31TCG_A044521_20231231T105442/IMG_DATA/R10m/T31TCG_20231231T105441_TCI_10m.tif",
#         ...
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWF_20231211T161419.SAFE/GRANULE/L2A_T30SWF_A044235_20231211T105433/IMG_DATA/R10m/T30SWF_20231211T105431_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/WE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SWE_20231211T161414.SAFE/GRANULE/L2A_T30SWE_A044235_20231211T105433/IMG_DATA/R10m/T30SWE_20231211T105431_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VF/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVF_20231211T161404.SAFE/GRANULE/L2A_T30SVF_A044235_20231211T105433/IMG_DATA/R10m/T30SVF_20231211T105431_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/S/VE/2023/12/11/S2A_MSIL2A_20231211T105431_N0509_R051_T30SVE_20231211T161405.SAFE/GRANULE/L2A_T30SVE_A044235_20231211T105433/IMG_DATA/R10m/T30SVE_20231211T105431_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/30/T/UQ/2023/12/10/S2A_MSIL2A_20231210T112451_N0509_R037_T30TUQ_20231210T171344.SAFE/GRANULE/L2A_T30TUQ_A044221_20231210T112445/IMG_DATA/R10m/T30TUQ_20231210T112451_TCI_10m.tif"
#       ]
#     -- child 3 type: list<item: double>
#       [
#         [
#           399960,
#           4790220,
#           509760,
#           4900020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ],
#         ...
#         [
#           399960,
#           3890220,
#           509760,
#           4000020
#         ],
#         [
#           300000,
#           4890240,
#           409800,
#           5000040
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         ...
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<item: double>
#       [
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4900020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ],
#         ...
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4000020
#         ],
#         [
#           10,
#           0,
#           300000,
#           0,
#           -10,
#           5000040
#         ]
#       ]
#     -- child 6 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         ...
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "True color image",
#         "True color image",
#         "True color image",
#         "True color image",
#         "True color image",
#         ...
#         "True color image",
#         "True color image",
#         "True color image",
#         "True color image",
#         "True color image"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         ...
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
# ]

# %% [markdown]
# ## Serialize as a geoparquet
#
# Use `stac_geoparquet.arrow.to_parquet` to serialize as geoparquet.
#
# See [https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.to_parquet](https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.to_parquet)

# %%
s2_parquet_path = "s2-stac-api.parquet"
to_parquet(table, s2_parquet_path)

# %% [markdown]
# ## Verify serialized geoparquet
#
# Use `pyarrow.parquet.read_table` from pyarrow.parquet, see [https://arrow.apache.org/docs/python/generated/pyarrow.parquet.read_table.html#pyarrow-parquet-read-table](https://arrow.apache.org/docs/python/generated/pyarrow.parquet.read_table.html#pyarrow-parquet-read-table)

# %%
read_table(s2_parquet_path) == table
# Out:
# True
