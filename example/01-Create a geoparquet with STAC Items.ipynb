# %% [markdown]
# # Create a geoparquet with STAC Items
#
# Goal:
#
# * Read STAC Items
# * Create an iterable of STAC Items
# * Create an Apache Arrow record batch reader
# * Create an Apache Arrow table
# * Serialize to geoparquet
#
# ## Configure the environment
#
# Create a Python environment with:
#
# * stac-geoparquet
# * pystac
# * ipykernel

# %% [markdown]
# ## Imports

# %%
from stac_geoparquet.arrow import parse_stac_items_to_arrow, to_parquet
from pystac import read_file
from pyarrow.parquet import read_table

# %% [markdown]
# ## Create an iterable of STAC Items
#
# Use `pystac.readfile` to read the local STAC Item files
#
# See [https://pystac.readthedocs.io/en/stable/api/pystac.html#pystac.read_file](https://pystac.readthedocs.io/en/stable/api/pystac.html#pystac.read_file)

# %%
item_paths = [
    "data-files/items/S2A_10TFK_20220524_0_L2A.json",
    "data-files/items/S2B_10TFK_20210713_0_L2A.json",
]

# %%
items_iterable = [read_file(item_path) for item_path in item_paths]

items_iterable
# Out:
# [<Item id=S2A_10TFK_20220524_0_L2A>, <Item id=S2B_10TFK_20210713_0_L2A>]

# %% [markdown]
# ## Create a record batch reader
#
# Use `stac_geoparquet.arrow.parse_stac_items_to_arrow` to create an Apache Arrow record batch reader
#
# See:
#
# * `stac_geoparquet.arrow.parse_stac_items_to_arrow` [https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.parse_stac_items_to_arrow](https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.parse_stac_items_to_arrow)
# * `RecordBatchReader` [https://arrow.apache.org/docs/python/generated/pyarrow.RecordBatchReader.html#pyarrow.RecordBatchReader](https://arrow.apache.org/docs/python/generated/pyarrow.RecordBatchReader.html#pyarrow.RecordBatchReader)

# %%
record_batch_reader = parse_stac_items_to_arrow(items_iterable)

# %% [markdown]
# ## Create a `pyarrow.lib.Table`
#
# See  [https://arrow.apache.org/docs/python/generated/pyarrow.Table.html#pyarrow-table](https://arrow.apache.org/docs/python/generated/pyarrow.Table.html#pyarrow-table)

# %%
table = record_batch_reader.read_all()

table.schema
# Out:
# assets: struct<AOT: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B01: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B02: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B03: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B04: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B05: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B06: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B07: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B08: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B09: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B11: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B12: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, B8A: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, SCL: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, WVP: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>, info: struct<href: string, roles: list<item: string>, title: string, type: string>, metadata: struct<href: string, roles: list<item: string>, title: string, type: string>, overview: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: st ...
#   child 0, AOT: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 2, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 3, roles: list<item: string>
#           child 0, item: string
#       child 4, title: string
#       child 5, type: string
#   child 1, B01: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 2, B02: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 3, B03: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 4, B04: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 5, B05: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, full_width_half_max: double
#               child 2, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 6, B06: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, full_width_half_max: double
#               child 2, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 7, B07: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, full_width_half_max: double
#               child 2, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 8, B08: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 9, B09: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, full_width_half_max: double
#               child 2, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 10, B11: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 11, B12: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 12, B8A: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, full_width_half_max: double
#               child 2, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 13, SCL: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 2, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 3, roles: list<item: string>
#           child 0, item: string
#       child 4, title: string
#       child 5, type: string
#   child 14, WVP: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 2, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 3, roles: list<item: string>
#           child 0, item: string
#       child 4, title: string
#       child 5, type: string
#   child 15, info: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 16, metadata: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 17, overview: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
#   child 18, thumbnail: struct<href: string, roles: list<item: string>, title: string, type: string>
#       child 0, href: string
#       child 1, roles: list<item: string>
#           child 0, item: string
#       child 2, title: string
#       child 3, type: string
#   child 19, visual: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#       child 0, eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#           child 0, item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>
#               child 0, center_wavelength: double
#               child 1, common_name: string
#               child 2, full_width_half_max: double
#               child 3, name: string
#       child 1, gsd: int64
#       child 2, href: string
#       child 3, proj:shape: list<item: int64>
#           child 0, item: int64
#       child 4, proj:transform: list<item: int64>
#           child 0, item: int64
#       child 5, roles: list<item: string>
#           child 0, item: string
#       child 6, title: string
#       child 7, type: string
# bbox: struct<xmin: double, ymin: double, xmax: double, ymax: double>
#   child 0, xmin: double
#   child 1, ymin: double
#   child 2, xmax: double
#   child 3, ymax: double
# collection: string
# geometry: binary
#   -- field metadata --
#   ARROW:extension:name: 'geoarrow.wkb'
#   ARROW:extension:metadata: '{"crs":{"$schema":"https://proj.org/schemas/' + 1380
# id: string
# links: list<item: struct<href: string, rel: string, title: string, type: string>>
#   child 0, item: struct<href: string, rel: string, title: string, type: string>
#       child 0, href: string
#       child 1, rel: string
#       child 2, title: string
#       child 3, type: string
# stac_extensions: list<item: string>
#   child 0, item: string
# stac_version: string
# type: string
# constellation: string
# created: timestamp[us, tz=UTC]
# datetime: timestamp[us, tz=UTC]
# eo:cloud_cover: double
# gsd: int64
# instruments: list<item: string>
#   child 0, item: string
# platform: string
# proj:code: string
# sentinel:boa_offset_applied: bool
# sentinel:data_coverage: int64
# sentinel:grid_square: string
# sentinel:latitude_band: string
# sentinel:processing_baseline: string
# sentinel:product_id: string
# sentinel:sequence: string
# sentinel:utm_zone: int64
# sentinel:valid_cloud_cover: bool
# updated: timestamp[us, tz=UTC]
# view:off_nadir: int64

# %% [markdown]
# Inspect the first row

# %%
table[0]
# Out:
# <pyarrow.lib.ChunkedArray object at 0x7f2077bdb7c0>
# [
#   -- is_valid: all not null
#   -- child 0 type: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/AOT.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/AOT.tif"
#       ]
#     -- child 1 type: list<item: int64>
#       [
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ]
#       ]
#     -- child 2 type: list<item: int64>
#       [
#         [
#           60,
#           0,
#           600000,
#           0,
#           -60,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           60,
#           0,
#           600000,
#           0,
#           -60,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 3 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 4 type: string
#       [
#         "Aerosol Optical Thickness (AOT)",
#         "Aerosol Optical Thickness (AOT)"
#       ]
#     -- child 5 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 1 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.4439
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: double
#           [
#             0.027
#           ]
#         -- child 3 type: string
#           [
#             "B01"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.4439
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: double
#           [
#             0.027
#           ]
#         -- child 3 type: string
#           [
#             "B01"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         60,
#         60
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B01.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B01.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           60,
#           0,
#           600000,
#           0,
#           -60,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           60,
#           0,
#           600000,
#           0,
#           -60,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 1 (coastal)",
#         "Band 1 (coastal)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 2 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.4966
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: double
#           [
#             0.098
#           ]
#         -- child 3 type: string
#           [
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.4966
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: double
#           [
#             0.098
#           ]
#         -- child 3 type: string
#           [
#             "B02"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B02.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B02.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 2 (blue)",
#         "Band 2 (blue)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 3 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: double
#           [
#             0.045
#           ]
#         -- child 3 type: string
#           [
#             "B03"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: double
#           [
#             0.045
#           ]
#         -- child 3 type: string
#           [
#             "B03"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B03.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B03.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 3 (green)",
#         "Band 3 (green)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 4 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.6645
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: double
#           [
#             0.038
#           ]
#         -- child 3 type: string
#           [
#             "B04"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.6645
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: double
#           [
#             0.038
#           ]
#         -- child 3 type: string
#           [
#             "B04"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B04.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B04.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 4 (red)",
#         "Band 4 (red)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 5 type: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.7039
#           ]
#         -- child 1 type: double
#           [
#             0.019
#           ]
#         -- child 2 type: string
#           [
#             "B05"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.7039
#           ]
#         -- child 1 type: double
#           [
#             0.019
#           ]
#         -- child 2 type: string
#           [
#             "B05"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B05.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B05.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 5",
#         "Band 5"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 6 type: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.7402
#           ]
#         -- child 1 type: double
#           [
#             0.018
#           ]
#         -- child 2 type: string
#           [
#             "B06"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.7402
#           ]
#         -- child 1 type: double
#           [
#             0.018
#           ]
#         -- child 2 type: string
#           [
#             "B06"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B06.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B06.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 6",
#         "Band 6"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 7 type: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.7825
#           ]
#         -- child 1 type: double
#           [
#             0.028
#           ]
#         -- child 2 type: string
#           [
#             "B07"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.7825
#           ]
#         -- child 1 type: double
#           [
#             0.028
#           ]
#         -- child 2 type: string
#           [
#             "B07"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B07.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B07.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 7",
#         "Band 7"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 8 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.8351
#           ]
#         -- child 1 type: string
#           [
#             "nir"
#           ]
#         -- child 2 type: double
#           [
#             0.145
#           ]
#         -- child 3 type: string
#           [
#             "B08"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.8351
#           ]
#         -- child 1 type: string
#           [
#             "nir"
#           ]
#         -- child 2 type: double
#           [
#             0.145
#           ]
#         -- child 3 type: string
#           [
#             "B08"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B08.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B08.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 8 (nir)",
#         "Band 8 (nir)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 9 type: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.945
#           ]
#         -- child 1 type: double
#           [
#             0.026
#           ]
#         -- child 2 type: string
#           [
#             "B09"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.945
#           ]
#         -- child 1 type: double
#           [
#             0.026
#           ]
#         -- child 2 type: string
#           [
#             "B09"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         60,
#         60
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B09.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B09.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           60,
#           0,
#           600000,
#           0,
#           -60,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           60,
#           0,
#           600000,
#           0,
#           -60,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 9",
#         "Band 9"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 10 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             1.6137
#           ]
#         -- child 1 type: string
#           [
#             "swir16"
#           ]
#         -- child 2 type: double
#           [
#             0.143
#           ]
#         -- child 3 type: string
#           [
#             "B11"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             1.6137
#           ]
#         -- child 1 type: string
#           [
#             "swir16"
#           ]
#         -- child 2 type: double
#           [
#             0.143
#           ]
#         -- child 3 type: string
#           [
#             "B11"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B11.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B11.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 11 (swir16)",
#         "Band 11 (swir16)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 11 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             2.22024
#           ]
#         -- child 1 type: string
#           [
#             "swir22"
#           ]
#         -- child 2 type: double
#           [
#             0.242
#           ]
#         -- child 3 type: string
#           [
#             "B12"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             2.22024
#           ]
#         -- child 1 type: string
#           [
#             "swir22"
#           ]
#         -- child 2 type: double
#           [
#             0.242
#           ]
#         -- child 3 type: string
#           [
#             "B12"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B12.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B12.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 12 (swir22)",
#         "Band 12 (swir22)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 12 type: struct<eo:bands: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.8648
#           ]
#         -- child 1 type: double
#           [
#             0.033
#           ]
#         -- child 2 type: string
#           [
#             "B8A"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.8648
#           ]
#         -- child 1 type: double
#           [
#             0.033
#           ]
#         -- child 2 type: string
#           [
#             "B8A"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/B8A.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/B8A.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Band 8A",
#         "Band 8A"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 13 type: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/SCL.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/SCL.tif"
#       ]
#     -- child 1 type: list<item: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 2 type: list<item: int64>
#       [
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           20,
#           0,
#           600000,
#           0,
#           -20,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 3 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 4 type: string
#       [
#         "Scene Classification Map (SCL)",
#         "Scene Classification Map (SCL)"
#       ]
#     -- child 5 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 14 type: struct<href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/WVP.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/WVP.tif"
#       ]
#     -- child 1 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 2 type: list<item: int64>
#       [
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 3 type: list<item: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 4 type: string
#       [
#         "Water Vapour (WVP)",
#         "Water Vapour (WVP)"
#       ]
#     -- child 5 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 15 type: struct<href: string, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/10/T/FK/2022/5/24/0/tileInfo.json",
#         "https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/10/T/FK/2021/7/13/0/tileInfo.json"
#       ]
#     -- child 1 type: list<item: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "Original JSON metadata",
#         "Original JSON metadata"
#       ]
#     -- child 3 type: string
#       [
#         "application/json",
#         "application/json"
#       ]
#   -- child 16 type: struct<href: string, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/10/T/FK/2022/5/24/0/metadata.xml",
#         "https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/10/T/FK/2021/7/13/0/metadata.xml"
#       ]
#     -- child 1 type: list<item: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "Original XML metadata",
#         "Original XML metadata"
#       ]
#     -- child 3 type: string
#       [
#         "application/xml",
#         "application/xml"
#       ]
#   -- child 17 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.6645,
#             0.56,
#             0.4966
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 3 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.6645,
#             0.56,
#             0.4966
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 3 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/L2A_PVI.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/L2A_PVI.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           343,
#           343
#         ],
#         [
#           343,
#           343
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           320,
#           0,
#           600000,
#           0,
#           -320,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           320,
#           0,
#           600000,
#           0,
#           -320,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "True color image",
#         "True color image"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 18 type: struct<href: string, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/10/T/FK/2022/5/24/0/preview.jpg",
#         "https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/10/T/FK/2021/7/13/0/preview.jpg"
#       ]
#     -- child 1 type: list<item: string>
#       [
#         [
#           "thumbnail"
#         ],
#         [
#           "thumbnail"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "Thumbnail",
#         "Thumbnail"
#       ]
#     -- child 3 type: string
#       [
#         "image/png",
#         "image/png"
#       ]
#   -- child 19 type: struct<eo:bands: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>, gsd: int64, href: string, proj:shape: list<item: int64>, proj:transform: list<item: int64>, roles: list<item: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<item: struct<center_wavelength: double, common_name: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.6645,
#             0.56,
#             0.4966
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 3 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.6645,
#             0.56,
#             0.4966
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 3 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ]
#       ]
#     -- child 1 type: int64
#       [
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/TCI.tif",
#         "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2021/7/S2B_10TFK_20210713_0_L2A/TCI.tif"
#       ]
#     -- child 3 type: list<item: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<item: int64>
#       [
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ],
#         [
#           10,
#           0,
#           600000,
#           0,
#           -10,
#           4500000,
#           0,
#           0,
#           1
#         ]
#       ]
#     -- child 5 type: list<item: string>
#       [
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "True color image",
#         "True color image"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
# ]

# %% [markdown]
# ## Serialize as a geoparquet
#
# Use `stac_geoparquet.arrow.to_parquet` to serialize as geoparquet.
#
# See [https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.to_parquet](https://stac-utils.github.io/stac-geoparquet/latest/api/arrow/#stac_geoparquet.arrow.to_parquet)

# %%
s2_parquet_path = "s2.parquet"
to_parquet(table, s2_parquet_path)

# %% [markdown]
# ## Verify serialized geoparquet
#
# Use `pyarrow.parquet.read_table` from pyarrow.parquet, see [https://arrow.apache.org/docs/python/generated/pyarrow.parquet.read_table.html#pyarrow-parquet-read-table](https://arrow.apache.org/docs/python/generated/pyarrow.parquet.read_table.html#pyarrow-parquet-read-table)

# %%
read_table(s2_parquet_path) == table
# Out:
# True
