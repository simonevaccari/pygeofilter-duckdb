# %% [markdown]
# # DuckDB and geoparquet

# %% [markdown]
# ## Imports

# %%
import os
import duckdb
import folium
import pystac
import folium.plugins as folium_plugins
import geopandas as gpd
import pygeofilter
from stac_geoparquet.arrow import stac_table_to_items
# from pygeofilter.backends.sql import to_sql_where
from pygeofilter.util import IdempotentDict
from collections import OrderedDict
from pygeofilter.parsers.cql2_json import parse as json_parse

# %%
# Install and load DuckDB spatial extension
duckdb.install_extension("spatial")
duckdb.load_extension("spatial")

# %%
s2_parquet_path = "s2-stac-api.parquet"

# %% [markdown]
# ## Query the geoparquet file

# %%
if not os.path.exists(s2_parquet_path):
    print("Run notebook 02-Create a geoparquet file.ipynb first")
    exit(1)

# %%
sql_query = f"SELECT * EXCLUDE(geometry), ST_AsWKB(geometry) as geometry FROM '{s2_parquet_path}'"

print(sql_query)

db = duckdb.query(sql_query)
# Out:
# SELECT * EXCLUDE(geometry), ST_AsWKB(geometry) as geometry FROM 's2-stac-api.parquet'

# %%
type(db)
# Out:
# duckdb.duckdb.DuckDBPyRelation

# %% [markdown]
# ## Convert DuckDB result to Arrow table

# %%
table = db.fetch_arrow_table()

#table_head = table.slice(0, 125)  # Get first 125 rows

# %%
# table.to_pandas()

# %%
table.slice(0, 4).to_pandas()
# Out:
#                                               assets  \
# 0  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 1  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 2  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 3  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
#
#                                                 bbox      collection  \
# 0  {'xmin': -10.25298175, 'ymin': 43.25815001, 'x...  sentinel-2-l2a
# 1  {'xmin': 0.45686052, 'ymin': 44.13799675, 'xma...  sentinel-2-l2a
# 2  {'xmin': 0.4959286, 'ymin': 43.2382626, 'xmax'...  sentinel-2-l2a
# 3  {'xmin': 0.53321795, 'ymin': 42.33836183, 'xma...  sentinel-2-l2a
#
#                                                   id  \
# 0  S2B_MSIL2A_20231231T114409_R123_T29TMJ_2023123...
# 1  S2A_MSIL2A_20231231T105441_R051_T31TCK_2023123...
# 2  S2A_MSIL2A_20231231T105441_R051_T31TCJ_2023123...
# 3  S2A_MSIL2A_20231231T105441_R051_T31TCH_2023123...
#
#                                                links  \
# 0  [{'href': 'https://planetarycomputer.microsoft...
# 1  [{'href': 'https://planetarycomputer.microsoft...
# 2  [{'href': 'https://planetarycomputer.microsoft...
# 3  [{'href': 'https://planetarycomputer.microsoft...
#
#                                      stac_extensions stac_version     type  \
# 0  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 1  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 2  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 3  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
#
#   constellation                         datetime  ...  \
# 0    Sentinel 2 2023-12-31 11:44:09.024000+00:00  ...
# 1    Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
# 2    Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
# 3    Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
#
#    s2:reflectance_conversion_factor s2:saturated_defective_pixel_percentage  \
# 0                          1.034040                                     0.0
# 1                          1.034038                                     0.0
# 2                          1.034038                                     0.0
# 3                          1.034038                                     0.0
#
#   s2:snow_ice_percentage s2:thin_cirrus_percentage  \
# 0               0.000000                 40.464744
# 1               0.129087                 13.664892
# 2               0.000010                 18.065368
# 3               0.055783                  4.123205
#
#    s2:unclassified_percentage  s2:vegetation_percentage s2:water_percentage  \
# 0                    0.000000                  0.000000            0.708269
# 1                    0.000000                  0.000000            0.001739
# 2                    0.000086                  0.000000            0.010481
# 3                    0.047372                  0.522049            0.014681
#
#   sat:orbit_state sat:relative_orbit  \
# 0      descending                123
# 1      descending                 51
# 2      descending                 51
# 3      descending                 51
#
#                                             geometry
# 0  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0e\x00...
# 1  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 2  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 3  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
#
# [4 rows x 42 columns]

# %%
table_head = table.slice(0, 125)  # Get first 125 rows
# for item in stac_table_to_items(table_head):
#     print(item)

# %%
table_head.to_pandas()
# Out:
#                                                 assets  \
# 0    {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 1    {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 2    {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 3    {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 4    {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# ..                                                 ...
# 120  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 121  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 122  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 123  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
# 124  {'AOT': {'gsd': 10.0, 'href': 'https://sentine...
#
#                                                   bbox      collection  \
# 0    {'xmin': -10.25298175, 'ymin': 43.25815001, 'x...  sentinel-2-l2a
# 1    {'xmin': 0.45686052, 'ymin': 44.13799675, 'xma...  sentinel-2-l2a
# 2    {'xmin': 0.4959286, 'ymin': 43.2382626, 'xmax'...  sentinel-2-l2a
# 3    {'xmin': 0.53321795, 'ymin': 42.33836183, 'xma...  sentinel-2-l2a
# 4    {'xmin': 0.5688037, 'ymin': 41.4388363, 'xmax'...  sentinel-2-l2a
# ..                                                 ...             ...
# 120  {'xmin': -4.67851734, 'ymin': 39.64771538, 'xm...  sentinel-2-l2a
# 121  {'xmin': -1.84912778, 'ymin': 38.74919438, 'xm...  sentinel-2-l2a
# 122  {'xmin': -1.8632824, 'ymin': 37.8524187, 'xmax...  sentinel-2-l2a
# 123  {'xmin': -1.8681232, 'ymin': 37.5303524, 'xmax...  sentinel-2-l2a
# 124  {'xmin': -3.00023345, 'ymin': 38.75403605, 'xm...  sentinel-2-l2a
#
#                                                     id  \
# 0    S2B_MSIL2A_20231231T114409_R123_T29TMJ_2023123...
# 1    S2A_MSIL2A_20231231T105441_R051_T31TCK_2023123...
# 2    S2A_MSIL2A_20231231T105441_R051_T31TCJ_2023123...
# 3    S2A_MSIL2A_20231231T105441_R051_T31TCH_2023123...
# 4    S2A_MSIL2A_20231231T105441_R051_T31TCG_2023123...
# ..                                                 ...
# 120  S2B_MSIL2A_20231229T110359_R094_T30TUK_2023122...
# 121  S2B_MSIL2A_20231229T110359_R094_T30SXJ_2023122...
# 122  S2B_MSIL2A_20231229T110359_R094_T30SXH_2023122...
# 123  S2B_MSIL2A_20231229T110359_R094_T30SXG_2023122...
# 124  S2B_MSIL2A_20231229T110359_R094_T30SWJ_2023122...
#
#                                                  links  \
# 0    [{'href': 'https://planetarycomputer.microsoft...
# 1    [{'href': 'https://planetarycomputer.microsoft...
# 2    [{'href': 'https://planetarycomputer.microsoft...
# 3    [{'href': 'https://planetarycomputer.microsoft...
# 4    [{'href': 'https://planetarycomputer.microsoft...
# ..                                                 ...
# 120  [{'href': 'https://planetarycomputer.microsoft...
# 121  [{'href': 'https://planetarycomputer.microsoft...
# 122  [{'href': 'https://planetarycomputer.microsoft...
# 123  [{'href': 'https://planetarycomputer.microsoft...
# 124  [{'href': 'https://planetarycomputer.microsoft...
#
#                                        stac_extensions stac_version     type  \
# 0    [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 1    [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 2    [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 3    [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 4    [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# ..                                                 ...          ...      ...
# 120  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 121  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 122  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 123  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
# 124  [https://stac-extensions.github.io/eo/v1.1.0/s...        1.1.0  Feature
#
#     constellation                         datetime  ...  \
# 0      Sentinel 2 2023-12-31 11:44:09.024000+00:00  ...
# 1      Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
# 2      Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
# 3      Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
# 4      Sentinel 2 2023-12-31 10:54:41.024000+00:00  ...
# ..            ...                              ...  ...
# 120    Sentinel 2 2023-12-29 11:03:59.024000+00:00  ...
# 121    Sentinel 2 2023-12-29 11:03:59.024000+00:00  ...
# 122    Sentinel 2 2023-12-29 11:03:59.024000+00:00  ...
# 123    Sentinel 2 2023-12-29 11:03:59.024000+00:00  ...
# 124    Sentinel 2 2023-12-29 11:03:59.024000+00:00  ...
#
#      s2:reflectance_conversion_factor s2:saturated_defective_pixel_percentage  \
# 0                            1.034040                                     0.0
# 1                            1.034038                                     0.0
# 2                            1.034038                                     0.0
# 3                            1.034038                                     0.0
# 4                            1.034038                                     0.0
# ..                                ...                                     ...
# 120                          1.033865                                     0.0
# 121                          1.033865                                     0.0
# 122                          1.033865                                     0.0
# 123                          1.033865                                     0.0
# 124                          1.033865                                     0.0
#
#     s2:snow_ice_percentage s2:thin_cirrus_percentage  \
# 0                 0.000000                 40.464744
# 1                 0.129087                 13.664892
# 2                 0.000010                 18.065368
# 3                 0.055783                  4.123205
# 4                 0.000000                  4.116742
# ..                     ...                       ...
# 120               0.000046                  0.587879
# 121               0.000000                  0.000008
# 122               0.000000                  0.000000
# 123               0.000000                  1.435122
# 124               0.000000                  0.406279
#
#      s2:unclassified_percentage  s2:vegetation_percentage s2:water_percentage  \
# 0                      0.000000                  0.000000            0.708269
# 1                      0.000000                  0.000000            0.001739
# 2                      0.000086                  0.000000            0.010481
# 3                      0.047372                  0.522049            0.014681
# 4                      0.269664                  0.144867            0.097903
# ..                          ...                       ...                 ...
# 120                    0.000000                  0.000000            0.000865
# 121                    0.000000                  0.000000            0.000000
# 122                    0.000000                  0.000000            0.000000
# 123                    0.005413                  0.000000            0.000000
# 124                    0.000000                  0.000000            0.000000
#
#     sat:orbit_state sat:relative_orbit  \
# 0        descending                123
# 1        descending                 51
# 2        descending                 51
# 3        descending                 51
# 4        descending                 51
# ..              ...                ...
# 120      descending                 94
# 121      descending                 94
# 122      descending                 94
# 123      descending                 94
# 124      descending                 94
#
#                                               geometry
# 0    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0e\x00...
# 1    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 2    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 3    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 4    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# ..                                                 ...
# 120  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0c\x00...
# 121  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0c\x00...
# 122  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\
,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SPD_20231213T042900>,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SPC_20231213T042948>,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SPB_20231213T042908>,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SPA_20231213T043337>,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SNV_20231213T042856>,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SNB_20231213T042007>,
#  <Item id=S2B_MSIL2A_20231212T111349_R137_T29SNA_20231213T042639>,
#  <Item id=S2B_MSIL2A_20231211T114359_R123_T29TMJ_20231211T144723>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TCK_20231211T161415>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TCJ_20231211T161419>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TCH_20231211T161552>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TCG_20231211T161418>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TCF_20231211T161416>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TCE_20231211T161409>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TBG_20231211T161420>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TBF_20231211T161418>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31TBE_20231211T161556>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SCD_20231211T161406>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SCC_20231211T161403>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SCB_20231211T161403>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SBV_20231211T161405>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SBD_20231211T161553>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SBC_20231211T161414>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SBB_20231211T161416>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T31SBA_20231211T161406>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TYQ_20231211T161558>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TYP_20231211T161417>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TYN_20231211T161417>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TYM_20231211T161440>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TYL_20231211T161419>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TYK_20231211T161559>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TXQ_20231211T161404>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TXP_20231211T161404>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TXN_20231211T161409>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TXM_20231211T161413>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TXL_20231211T161418>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TXK_20231211T161600>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TWL_20231211T161403>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30TWK_20231211T161405>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SYJ_20231211T161417>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SYH_20231211T161558>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SYG_20231211T161609>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SYF_20231211T161412>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SYE_20231211T161413>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SXJ_20231211T161419>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SXH_20231211T161603>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SXG_20231211T161601>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SXF_20231211T161414>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SXE_20231211T161415>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SWJ_20231211T161555>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SWH_20231211T161548>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SWG_20231211T161558>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SWF_20231211T161419>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SWE_20231211T161414>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SVF_20231211T161404>,
#  <Item id=S2A_MSIL2A_20231211T105431_R051_T30SVE_20231211T161405>,
#  <Item id=S2A_MSIL2A_20231210T112451_R037_T30TUQ_20231210T171344>]

# %%
items = [pystac.Item.from_dict(item) for item in stac_table_to_items(table_head)]
items[0]
# Out:
# <Item id=S2B_MSIL2A_20231231T114409_R123_T29TMJ_20231231T150806>

# %%
# items = [pystac.Item.from_dict(item) for item in stac_table_to_items(table_head)]
print(len(all_items))
map = folium.Map(zoom_start=6)
layer_control = folium.LayerControl(position="topright", collapsed=True)
fullscreen = folium_plugins.Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints = folium.GeoJson(
    gpd.GeoDataFrame.from_features(all_items).to_json(),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds())
map
# Out:
# 1000
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1a356e6ab0b343379999f174eed83ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1a356e6ab0b343379999f174eed83ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1a356e6ab0b343379999f174eed83ed = L.map(
#                 &quot;map_c1a356e6ab0b343379999f174eed83ed&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebcb716508ed76a415a239d98ba7cfa6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebcb716508ed76a415a239d98ba7cfa6.addTo(map_c1a356e6ab0b343379999f174eed83ed);
#
#
#         function geo_json_b768f8dc8e62b091f9eef39d915c9a4f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ff&quot;, &quot;fillColor&quot;: &quot;#00000000&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b768f8dc8e62b091f9eef39d915c9a4f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_
]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;Sentinel 2&quot;, &quot;datetime&quot;: &quot;2023-12-31T10:54:41.024000Z&quot;, &quot;eo:cloud_cover&quot;: 95.945507, &quot;instruments&quot;: [&quot;msi&quot;], &quot;

# %% [markdown]
# ### Geofilter

# %%
from pygeofilter.parsers.cql2_json import parse as json_parse
from pygeofilter.util import IdempotentDict
from collections import OrderedDict
from pygeofilter_duckdb import to_sql_where

cql2_filter = {
    "op": "and",
    "args": [
        {
            "op": "between",
            "args": [
                {"property": "datetime"},
                ["2023-12-28T00:00:00Z", "2023-12-28T23:59:59Z"],
            ],
        },
        {"op": "between", "args": [{"property": "eo:cloud_cover"}, [90, 100]]},
        {
            "op": "s_intersects",
            "args": [
                {"property": "geometry"},
                {
                    "type": "Polygon",
                    "coordinates": [
                        [
                            [-9.51346013858793, 38.95450355515311],
                            [-9.51346013858793, 38.22500810801125],
                            [-8.359265560322228, 38.22500810801125],
                            [-8.359265560322228, 38.95450355515311],
                            [-9.51346013858793, 38.95450355515311],
                        ]
                    ],
                },
            ],
        },
    ],
}

# Convert to SQL WHERE clause
sql_where = to_sql_where(json_parse(cql2_filter), IdempotentDict())
print(sql_where)
# Out:
# ((("datetime" BETWEEN '2023-12-28T00:00:00Z' AND '2023-12-28T23:59:59Z') AND ("eo:cloud_cover" BETWEEN 90 AND 100)) AND ST_Intersects("geometry",ST_GeomFromHEXEWKB('01030000000100000005000000D0114E3FE40623C030A6282C2D7A4340D0114E3FE40623C0209FD010CD1C43408053D0A7F1B720C0209FD010CD1C43408053D0A7F1B720C030A6282C2D7A4340D0114E3FE40623C030A6282C2D7A4340')))

# %%
sql_query = f"SELECT * EXCLUDE(geometry), ST_AsWKB(geometry) as geometry FROM '{s2_parquet_path}' WHERE {sql_where}"
db_filtered = duckdb.query(sql_query)

# %%
subset_table = db_filtered.fetch_arrow_table()
subset_table[0]
# Out:
# <pyarrow.lib.ChunkedArray object at 0x7f543ca060e0>
# [
#   -- is_valid: all not null
#   -- child 0 type: struct<gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: double
#       [
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 1 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R10m/T29SND_20231228T113409_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R10m/T29SNC_20231228T113409_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R10m/T29SMD_20231228T113409_AOT_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R10m/T29SMC_20231228T113409_AOT_10m.tif"
#       ]
#     -- child 2 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 3 type: list<l: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 4 type: list<l: double>
#       [
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4300020
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4300020
#         ]
#       ]
#     -- child 5 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 6 type: string
#       [
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)",
#         "Aerosol optical thickness (AOT)"
#       ]
#     -- child 7 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 1 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.443
#           ]
#         -- child 1 type: string
#           [
#             "coastal"
#           ]
#         -- child 2 type: string
#           [
#             "Band 1 - Coastal aerosol"
#           ]
#         -- child 3 type: double
#           [
#             0.027
#           ]
#         -- child 4 type: string
#           [
#             "B01"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         60,
#         60,
#         60,
#         60
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R60m/T29SND_20231228T113409_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R60m/T29SNC_20231228T113409_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R60m/T29SMD_20231228T113409_B01_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R60m/T29SMC_20231228T113409_B01_60m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ],
#         [
#           1830,
#           1830
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           60,
#           0,
#           499980,
#           0,
#           -60,
#           4400040
#         ],
#         [
#           60,
#           0,
#           499980,
#           0,
#           -60,
#           4300020
#         ],
#         [
#           60,
#           0,
#           399960,
#           0,
#           -60,
#           4400040
#         ],
#         [
#           60,
#           0,
#           399960,
#           0,
#           -60,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m",
#         "Band 1 - Coastal aerosol - 60m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 2 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B02"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R10m/T29SND_20231228T113409_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R10m/T29SNC_20231228T113409_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R10m/T29SMD_20231228T113409_B02_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R10m/T29SMC_20231228T113409_B02_10m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4300020
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m",
#         "Band 2 - Blue - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 3 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.56
#           ]
#         -- child 1 type: string
#           [
#             "green"
#           ]
#         -- child 2 type: string
#           [
#             "Band 3 - Green"
#           ]
#         -- child 3 type: double
#           [
#             0.045
#           ]
#         -- child 4 type: string
#           [
#             "B03"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R10m/T29SND_20231228T113409_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R10m/T29SNC_20231228T113409_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R10m/T29SMD_20231228T113409_B03_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R10m/T29SMC_20231228T113409_B03_10m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4300020
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m",
#         "Band 3 - Green - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 4 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665
#           ]
#         -- child 1 type: string
#           [
#             "red"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red"
#           ]
#         -- child 3 type: double
#           [
#             0.038
#           ]
#         -- child 4 type: string
#           [
#             "B04"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R10m/T29SND_20231228T113409_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R10m/T29SNC_20231228T113409_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R10m/T29SMD_20231228T113409_B04_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R10m/T29SMC_20231228T113409_B04_10m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4300020
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m",
#         "Band 4 - Red - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 5 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.704
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 5 - Vegetation red edge 1"
#           ]
#         -- child 3 type: double
#           [
#             0.019
#           ]
#         -- child 4 type: string
#           [
#             "B05"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         20,
#         20,
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R20m/T29SND_20231228T113409_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R20m/T29SNC_20231228T113409_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R20m/T29SMD_20231228T113409_B05_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R20m/T29SMC_20231228T113409_B05_20m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           20,
#           0,
#           499980,
#           0,
#           -20,
#           4400040
#         ],
#         [
#           20,
#           0,
#           499980,
#           0,
#           -20,
#           4300020
#         ],
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4400040
#         ],
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m",
#         "Band 5 - Vegetation red edge 1 - 20m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 6 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.74
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 6 - Vegetation red edge 2"
#           ]
#         -- child 3 type: double
#           [
#             0.018
#           ]
#         -- child 4 type: string
#           [
#             "B06"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         20,
#         20,
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R20m/T29SND_20231228T113409_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R20m/T29SNC_20231228T113409_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R20m/T29SMD_20231228T113409_B06_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R20m/T29SMC_20231228T113409_B06_20m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           20,
#           0,
#           499980,
#           0,
#           -20,
#           4400040
#         ],
#         [
#           20,
#           0,
#           499980,
#           0,
#           -20,
#           4300020
#         ],
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4400040
#         ],
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 6 - Vegetation red edge 2 - 20m",
#         "Band 6 - Vegetation red edge 2 - 20m",
#         "Band 6 - Vegetation red edge 2 - 20m",
#         "Band 6 - Vegetation red edge 2 - 20m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 7 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.783
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 7 - Vegetation red edge 3"
#           ]
#         -- child 3 type: double
#           [
#             0.028
#           ]
#         -- child 4 type: string
#           [
#             "B07"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.783
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 7 - Vegetation red edge 3"
#           ]
#         -- child 3 type: double
#           [
#             0.028
#           ]
#         -- child 4 type: string
#           [
#             "B07"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.783
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 7 - Vegetation red edge 3"
#           ]
#         -- child 3 type: double
#           [
#             0.028
#           ]
#         -- child 4 type: string
#           [
#             "B07"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.783
#           ]
#         -- child 1 type: string
#           [
#             "rededge"
#           ]
#         -- child 2 type: string
#           [
#             "Band 7 - Vegetation red edge 3"
#           ]
#         -- child 3 type: double
#           [
#             0.028
#           ]
#         -- child 4 type: string
#           [
#             "B07"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         20,
#         20,
#         20,
#         20
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R20m/T29SND_20231228T113409_B07_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R20m/T29SNC_20231228T113409_B07_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R20m/T29SMD_20231228T113409_B07_20m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R20m/T29SMC_20231228T113409_B07_20m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ],
#         [
#           5490,
#           5490
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           20,
#           0,
#           499980,
#           0,
#           -20,
#           4400040
#         ],
#         [
#           20,
#           0,
#           499980,
#           0,
#           -20,
#           4300020
#         ],
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4400040
#         ],
#         [
#           20,
#           0,
#           399960,
#           0,
#           -20,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 7 - Vegetation red edge 3 - 20m",
#         "Band 7 - Vegetation red edge 3 - 20m",
#         "Band 7 - Vegetation red edge 3 - 20m",
#         "Band 7 - Vegetation red edge 3 - 20m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 8 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.842
#           ]
#         -- child 1 type: string
#           [
#             "nir"
#           ]
#         -- child 2 type: string
#           [
#             "Band 8 - NIR"
#           ]
#         -- child 3 type: double
#           [
#             0.145
#           ]
#         -- child 4 type: string
#           [
#             "B08"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.842
#           ]
#         -- child 1 type: string
#           [
#             "nir"
#           ]
#         -- child 2 type: string
#           [
#             "Band 8 - NIR"
#           ]
#         -- child 3 type: double
#           [
#             0.145
#           ]
#         -- child 4 type: string
#           [
#             "B08"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.842
#           ]
#         -- child 1 type: string
#           [
#             "nir"
#           ]
#         -- child 2 type: string
#           [
#             "Band 8 - NIR"
#           ]
#         -- child 3 type: double
#           [
#             0.145
#           ]
#         -- child 4 type: string
#           [
#             "B08"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.842
#           ]
#         -- child 1 type: string
#           [
#             "nir"
#           ]
#         -- child 2 type: string
#           [
#             "Band 8 - NIR"
#           ]
#         -- child 3 type: double
#           [
#             0.145
#           ]
#         -- child 4 type: string
#           [
#             "B08"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R10m/T29SND_20231228T113409_B08_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R10m/T29SNC_20231228T113409_B08_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R10m/T29SMD_20231228T113409_B08_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R10m/T29SMC_20231228T113409_B08_10m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4300020
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "Band 8 - NIR - 10m",
#         "Band 8 - NIR - 10m",
#         "Band 8 - NIR - 10m",
#         "Band 8 - NIR - 10m"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 9 type: struct<eo:bands: list<l: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.945
#           ]
#         -- child 1 type: string
#           [
#             "Band 9 - Water vapor"
#           ]
#         -- child 2 type: double
#           [
#             0.026
#           ]
#         -- child 3 type: string
#           [
#             "B09"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.945
#           ]
#         -- child 1 type: string
#           [
#             "Band 9 - Water vapor"
#           ]
#         -- child 2 type: double
#           [
#             0.026
#           ]
#         -- child 3 type: string
#           [
#             "B09"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.945
#           ]
#         -- child 1 type: string
#           [
#             "Band 9 - Water vapor"
#           ]
#         -- child 2 type: double
#           [
#             0.026
#           ]
#         -- child 3 type: string
#           [
#             "B09"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.945
#           ]
#         -- child 1 type: string
#           [
#             "Band 9 - Water vapor"
#           ]
#         -- child 2 type: double
#           [
#             0.026
#           ]
#         -- child 3 type: string
#           [
#             "B09"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         60,
#         60,
#         60,
#         60
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R60m/T29SND_20231228T113409_B09_60m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R60m/T29SNC_20231228T113409_B09_60m.tif",
# ...
#       ]
#     -- child 1 type: list<l: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "Granule metadata",
#         "Granule metadata",
#         "Granule metadata",
#         "Granule metadata"
#       ]
#     -- child 3 type: string
#       [
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml"
#       ]
#   -- child 17 type: struct<href: string, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/INSPIRE.xml",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/INSPIRE.xml",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/INSPIRE.xml",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/INSPIRE.xml"
#       ]
#     -- child 1 type: list<l: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "INSPIRE metadata",
#         "INSPIRE metadata",
#         "INSPIRE metadata",
#         "INSPIRE metadata"
#       ]
#     -- child 3 type: string
#       [
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml"
#       ]
#   -- child 18 type: struct<href: string, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/QI_DATA/T29SND_20231228T113409_PVI.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/QI_DATA/T29SNC_20231228T113409_PVI.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/QI_DATA/T29SMD_20231228T113409_PVI.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/QI_DATA/T29SMC_20231228T113409_PVI.tif"
#       ]
#     -- child 1 type: list<l: string>
#       [
#         [
#           "thumbnail"
#         ],
#         [
#           "thumbnail"
#         ],
#         [
#           "thumbnail"
#         ],
#         [
#           "thumbnail"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "Thumbnail",
#         "Thumbnail",
#         "Thumbnail",
#         "Thumbnail"
#       ]
#     -- child 3 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
#   -- child 19 type: struct<href: string, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/MTD_MSIL2A.xml",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/MTD_MSIL2A.xml",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/MTD_MSIL2A.xml",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/MTD_MSIL2A.xml"
#       ]
#     -- child 1 type: list<l: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "Product metadata",
#         "Product metadata",
#         "Product metadata",
#         "Product metadata"
#       ]
#     -- child 3 type: string
#       [
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml"
#       ]
#   -- child 20 type: struct<href: string, rel: string, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SND_20231228T144647&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SNC_20231228T142841&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SMD_20231228T145559&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SMC_20231228T144508&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png"
#       ]
#     -- child 1 type: string
#       [
#         "preview",
#         "preview",
#         "preview",
#         "preview"
#       ]
#     -- child 2 type: list<l: string>
#       [
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ],
#         [
#           "overview"
#         ]
#       ]
#     -- child 3 type: string
#       [
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview",
#         "Rendered preview"
#       ]
#     -- child 4 type: string
#       [
#         "image/png",
#         "image/png",
#         "image/png",
#         "image/png"
#       ]
#   -- child 21 type: struct<href: string, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/manifest.safe",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/manifest.safe"
#       ]
#     -- child 1 type: list<l: string>
#       [
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ],
#         [
#           "metadata"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest",
#         "SAFE manifest"
#       ]
#     -- child 3 type: string
#       [
#         "application/xml",
#         "application/xml",
#         "application/xml",
#         "application/xml"
#       ]
#   -- child 22 type: struct<href: string, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: string
#       [
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SND_20231228T144647&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SNC_20231228T142841&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SMD_20231228T145559&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png",
#         "https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=sentinel-2-l2a&item=S2B_MSIL2A_20231228T113409_R080_T29SMC_20231228T144508&assets=visual&asset_bidx=visual%7C1%2C2%2C3&nodata=0&format=png"
#       ]
#     -- child 1 type: list<l: string>
#       [
#         [
#           "tiles"
#         ],
#         [
#           "tiles"
#         ],
#         [
#           "tiles"
#         ],
#         [
#           "tiles"
#         ]
#       ]
#     -- child 2 type: string
#       [
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering",
#         "TileJSON with default rendering"
#       ]
#     -- child 3 type: string
#       [
#         "application/json",
#         "application/json",
#         "application/json",
#         "application/json"
#       ]
#   -- child 23 type: struct<eo:bands: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>, gsd: double, href: string, proj:bbox: list<l: double>, proj:shape: list<l: int64>, proj:transform: list<l: double>, roles: list<l: string>, title: string, type: string>
#     -- is_valid: all not null
#     -- child 0 type: list<l: struct<center_wavelength: double, common_name: string, description: string, full_width_half_max: double, name: string>>
#       [
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ],
#         -- is_valid: all not null
#         -- child 0 type: double
#           [
#             0.665,
#             0.56,
#             0.49
#           ]
#         -- child 1 type: string
#           [
#             "red",
#             "green",
#             "blue"
#           ]
#         -- child 2 type: string
#           [
#             "Band 4 - Red",
#             "Band 3 - Green",
#             "Band 2 - Blue"
#           ]
#         -- child 3 type: double
#           [
#             0.038,
#             0.045,
#             0.098
#           ]
#         -- child 4 type: string
#           [
#             "B04",
#             "B03",
#             "B02"
#           ]
#       ]
#     -- child 1 type: double
#       [
#         10,
#         10,
#         10,
#         10
#       ]
#     -- child 2 type: string
#       [
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/ND/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SND_20231228T144647.SAFE/GRANULE/L2A_T29SND_A035570_20231228T113409/IMG_DATA/R10m/T29SND_20231228T113409_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/NC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SNC_20231228T142841.SAFE/GRANULE/L2A_T29SNC_A035570_20231228T113409/IMG_DATA/R10m/T29SNC_20231228T113409_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MD/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMD_20231228T145559.SAFE/GRANULE/L2A_T29SMD_A035570_20231228T113409/IMG_DATA/R10m/T29SMD_20231228T113409_TCI_10m.tif",
#         "https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/29/S/MC/2023/12/28/S2B_MSIL2A_20231228T113409_N0510_R080_T29SMC_20231228T144508.SAFE/GRANULE/L2A_T29SMC_A035570_20231228T113409/IMG_DATA/R10m/T29SMC_20231228T113409_TCI_10m.tif"
#       ]
#     -- child 3 type: list<l: double>
#       [
#         [
#           499980,
#           4290240,
#           609780,
#           4400040
#         ],
#         [
#           499980,
#           4190220,
#           609780,
#           4300020
#         ],
#         [
#           399960,
#           4290240,
#           509760,
#           4400040
#         ],
#         [
#           399960,
#           4190220,
#           509760,
#           4300020
#         ]
#       ]
#     -- child 4 type: list<l: int64>
#       [
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ],
#         [
#           10980,
#           10980
#         ]
#       ]
#     -- child 5 type: list<l: double>
#       [
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           499980,
#           0,
#           -10,
#           4300020
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4400040
#         ],
#         [
#           10,
#           0,
#           399960,
#           0,
#           -10,
#           4300020
#         ]
#       ]
#     -- child 6 type: list<l: string>
#       [
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ],
#         [
#           "data"
#         ]
#       ]
#     -- child 7 type: string
#       [
#         "True color image",
#         "True color image",
#         "True color image",
#         "True color image"
#       ]
#     -- child 8 type: string
#       [
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized",
#         "image/tiff; application=geotiff; profile=cloud-optimized"
#       ]
# ]

# %%
items = [pystac.Item.from_dict(item) for item in stac_table_to_items(subset_table)]
print(len(items))
display(items[0])
# Out:
# 4
# <Item id=S2B_MSIL2A_20231228T113409_R080_T29SND_20231228T144647>

# %%
map = folium.Map()
layer_control = folium.LayerControl(position="topright", collapsed=True)
fullscreen = folium_plugins.Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints = folium.GeoJson(
    gpd.GeoDataFrame.from_features(items).to_json(),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05603591fc035efb61adbed2bc09a049 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05603591fc035efb61adbed2bc09a049&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05603591fc035efb61adbed2bc09a049 = L.map(
#                 &quot;map_05603591fc035efb61adbed2bc09a049&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a22142fd4f26f51ac2ad1040f3376b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a22142fd4f26f51ac2ad1040f3376b8.addTo(map_05603591fc035efb61adbed2bc09a049);
#
#
#         function geo_json_c11a573ce57a0fee907f8469f700904d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ff&quot;, &quot;fillColor&quot;: &quot;#00000000&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c11a573ce57a0fee907f8469f700904d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c11a573ce57a0fee907f8469f700904d = L.geoJson(null, {
#                 onEachFeature: geo_json_c11a573ce57a0fee907f8469f700904d_onEachFeature,
#
#                 style: geo_json_c11a573ce57a0fee907f8469f700904d_styler,
#             ...{
# }
#         });
#
#         function geo_json_c11a573ce57a0fee907f8469f700904d_add (data) {
#             geo_json_c11a573ce57a0fee907f8469f700904d
#                 .addData(data);
#         }
#             geo_json_c11a573ce57a0fee907f8469f700904d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[